# %% [markdown]
# # 04 — Análisis de errores e interpretabilidad (Lending Club)
#
# Responsable sugerido: **Rol D (Análisis, interpretabilidad e informe)**. Explica dónde y por qué falla el modelo. Basado en `proposal.md` §12 y la rúbrica de entrega final.

# %%
import sys, os
from pathlib import Path
ROOT = Path.cwd()
if not (ROOT / "src").exists() and (ROOT.parent / "src").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT)); os.chdir(ROOT)

import numpy as np, pandas as pd
import matplotlib.pyplot as plt, seaborn as sns
from src import config
sns.set_theme(style="whitegrid"); np.random.seed(config.SEED)
print("Listo. Semilla:", config.SEED)

# %% [markdown]
# ## 1. Evaluación final en test
#
# Métricas del modelo elegido sobre el test 2018; curvas ROC y PR; matriz de confusión a un umbral operativo.

# %%
# TODO: cargar modelo final (joblib) y evaluar en test

# %% [markdown]
# ## 2. Errores por segmento
#
# Desglosar métricas por `grade`, tramo de ingreso, `purpose` y año de emisión. ¿El modelo es peor en algún grupo?

# %%
# TODO: groupby por segmento -> AUC/recall por grupo

# %% [markdown]
# ## 3. Interpretabilidad
#
# Coeficientes (logística) o importancias/**SHAP** (boosting). Traducir a lectura de negocio.

# %%
# TODO: importancias / SHAP del modelo final

# %% [markdown]
# ## 4. Casos problemáticos
#
# Inspeccionar falsos negativos costosos (defaults que el modelo aprobó) y falsos positivos.

# %%
# TODO: revisar ejemplos de FN y FP

# %% [markdown]
# ## 5. Sesgos y equidad
#
# Discutir sesgo de selección (solo aprobados) y disparidades por segmento; límites de generalización.

# %%
# TODO: análisis de equidad por segmento

# %% [markdown]
# ## 6. Conclusiones para el informe
#
# Insumos concretos para `reports/informe_final.md` §11–§14.

# %%
# TODO: resumen de hallazgos
